# %% [markdown]
# # Report
#
# ## Learning Algorithm
#
# This project submission uses "vanilla" DQN, as expressed in the paper ["Human-level control through deep reinforcement
# learning."](https://storage.googleapis.com/deepmind-media/dqn/DQNNaturePaper.pdf)
#
# ![Screen%20Shot%202018-12-13%20at%2011.26.46%20AM.png](attachment:Screen%20Shot%202018-12-13%20at%2011.26.46%20AM.png)

# %% [markdown]
# ## Hyperparameters
#
# The hyperparameters are:

# %%
BUFFER_SIZE = int(1e5)  # replay buffer size
BATCH_SIZE = 64         # minibatch size
SEED = 0xdeadbeef       # random seed
GAMMA = 0.99            # discount factor
TAU = 1e-3              # for soft update of target parameters
LR = 5e-4               # learning rate 
UPDATE_EVERY = 4        # how often to update the Q-hat network

# %% [markdown]
# ## Neural Net Architecture
#
# The Q and Q_target networks have this structure:
#
# ```
# Sequential(
#   (fc1): Linear(in_features=37, out_features=64, bias=True)
#   (relu1): ReLU()
#   (fc2): Linear(in_features=64, out_features=128, bias=True)
#   (relu2): ReLU()
#   (logits): Linear(in_features=128, out_features=4, bias=True)
# )
# ```

# %% [markdown]
# ## Plot of Rewards
#
# The agent achieves a score of +13 at approximately episode 550, then plateaus at a score of about +16.
#
# ![plot.png](attachment:plot.png)

# %% [markdown]
# ## Ideas for Future Work
#
# To improve the performance of the agent, I would implement the following improvements:
#
# * Prioritize replay buffer sampling
# * Implement double DQN
